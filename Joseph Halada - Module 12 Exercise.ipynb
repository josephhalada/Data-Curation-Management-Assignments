# %%
# import statements
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# create spotify_df using the spotify_data.csv file
spotify_df = pd.read_csv("spotify_data.csv")
spotify_df
# Out:
#         artist_followers         genres      artist_name  artist_popularity  \
# 0                 248568     pop & rock      Raghu Dixit                 52
# 1                 248568     pop & rock      Raghu Dixit                 52
# 2                 248568     pop & rock      Raghu Dixit                 52
# 3                 248568     pop & rock      Raghu Dixit                 52
# 4                 248568     pop & rock      Raghu Dixit                 52
# ...                  ...            ...              ...                ...
# 245097             66464  miscellaneous  Keira Knightley                 53
# 245098              4491  miscellaneous         IVOXYGEN                 51
# 245099             12742            pop            MAY-A                 55
# 245100             12742            pop            MAY-A                 55
# 245101             73350  miscellaneous          90sFlav                 59
#
#                   track_name  track_popularity release_date  danceability  \
# 0                    Eno Ide                29         2008         0.639
# 1          Ee Tanuvu Ninnade                28         2008         0.508
# 2          Munjaane Manjalli                42     1/5/2010         0.390
# 3       Gudugudiya Sedi Nodo                38         2010         0.676
# 4                      Ambar                38         2010         0.507
# ...                      ...               ...          ...           ...
# 245097       Coming Up Roses                51     7/1/2014         0.477
# 245098             Young Kid                57    2/28/2020         0.782
# 245099              Apricots                54    10/6/2020         0.482
# 245100  Time I Love to Waste                59    2/18/2021         0.650
# 245101               Call me                70     2/9/2018         0.748
#
#         loudness   energy_lvl
# 0        -11.386   Low energy
# 1        -10.192  High energy
# 2         -8.671  High energy
# 3         -5.043  High energy
# 4         -6.902   Low energy
# ...          ...          ...
# 245097    -5.323  High energy
# 245098    -7.077  High energy
# 245099    -5.808  High energy
# 245100    -5.094  High energy
# 245101   -12.074   Low energy
#
# [245102 rows x 10 columns]

# %%
display(spotify_df.groupby("genres")[["danceability"]].mean())
# Out:
#                danceability
# genres
# country            0.601226
# electronic         0.608183
# folk               0.525161
# hip hop            0.718769
# hoerspiel          0.661333
# jazz               0.517055
# latin              0.608025
# metal              0.419201
# miscellaneous      0.574622
# pop                0.588275
# pop & rock         0.545256
# rap                0.726907
# rock               0.520274

# %% [markdown]
# rap has the highest danceability, followed by hip hop, which is then followed by hoerspiel
