# %%
import pandas as pd

# %%
# Read movies from dataset into a pandas dataframe. How many movies are in this dataset?
movies_dataframe = pd.read_json("https://raw.githubusercontent.com/vega/vega-datasets/master/data/movies.json")
len(movies_dataframe)
# Out:
# 3201

# %% [markdown]
# There are 3201 movies in this dataset.

# %%
# Drop all columns except 'Title', 'US Gross', 'Worldwide Gross', ‘US DVD Sales’, 'Production Budget', and ’IMDB Rating'. 
movies_dataframe = movies_dataframe[["Title", "US Gross", "Worldwide Gross", "US DVD Sales", "Production Budget", "IMDB Rating"]]
movies_dataframe
# Out:
#                            Title    US Gross  Worldwide Gross  US DVD Sales  \
# 0                 The Land Girls    146083.0         146083.0           NaN
# 1         First Love, Last Rites     10876.0          10876.0           NaN
# 2     I Married a Strange Person    203134.0         203134.0           NaN
# 3           Let's Talk About Sex    373615.0         373615.0           NaN
# 4                           Slam   1009819.0        1087521.0           NaN
# ...                          ...         ...              ...           ...
# 3196  Zack and Miri Make a Porno  31452765.0       36851125.0    21240321.0
# 3197                      Zodiac  33080084.0       83080084.0    20983030.0
# 3198                        Zoom  11989328.0       12506188.0     6679409.0
# 3199         The Legend of Zorro  45575336.0      141475336.0           NaN
# 3200           The Mask of Zorro  93828745.0      233700000.0           NaN
#
#       Production Budget  IMDB Rating
# ...

# %%
# Set 'Title' as the index of your dataframe.
movies_dataframe.set_index("Title")
# Out:
#                               US Gross  Worldwide Gross  US DVD Sales  \
# Title
# The Land Girls                146083.0         146083.0           NaN
# First Love, Last Rites         10876.0          10876.0           NaN
# I Married a Strange Person    203134.0         203134.0           NaN
# Let's Talk About Sex          373615.0         373615.0           NaN
# Slam                         1009819.0        1087521.0           NaN
# ...                                ...              ...           ...
# Zack and Miri Make a Porno  31452765.0       36851125.0    21240321.0
# Zodiac                      33080084.0       83080084.0    20983030.0
# Zoom                        11989328.0       12506188.0     6679409.0
# The Legend of Zorro         45575336.0      141475336.0           NaN
# The Mask of Zorro           93828745.0      233700000.0           NaN
#
#                             Production Budget  IMDB Rating
# Title
# ...

# %%
# Assume return on investment (ROI) for a movie is defined as:
# 𝑅𝑂𝐼 = 𝑊𝑜𝑟𝑙𝑑𝑤𝑖𝑑𝑒 𝑔𝑟𝑜𝑠𝑠 − 𝑃𝑟𝑜𝑑𝑢𝑐𝑡𝑖𝑜𝑛 𝑏𝑢𝑑𝑔𝑒𝑡
# What is the mean ROI? Which movie has the maximum ROI? Is it the one with the minimum production budget?

# %%
# What is the ROI of the movie with the maximum US DVD sales?
# Is it in the top 25% movies in terms of ROI? Is it in the bottom 25% movies in terms of production budget?

# %%
# What is the median difference between worldwide gross and US gross? Which movie has the highest difference?

# %%
# Do a majority of the movies have IMDB ratings higher than the average? Justify your answer.
